# %% [markdown]
# This notebook contains the steps necessary to scrape the neighborhoods in Toronto, manipulate into a dataframe, and then perform clustering and exploration + visualization of the neighborhoods

# %%
#import libraries for sraping and dataframe manipulation, save folium and visualization imports for later
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
print('Imports complete')
# Out:
# Imports complete

# %%
#code to navigate to wiki page and scrape data

res = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content, 'html.parser')
table = soup.find('table')
table_rows = table.find_all('tr')

rowlist = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        rowlist.append(row)

#now that we have the list of rows, convert it into a dataframe
FullTorontoList = pd.DataFrame(rowlist, columns=['Postalcode', 'Borough', 'Neighborhood'])
FullTorontoList.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 0        M1A      Not assigned      Not assigned
# 1        M2A      Not assigned      Not assigned
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %%
#pull out all rows where the Borough is "Not Assigned"

indexNames= FullTorontoList[ FullTorontoList['Borough'] == 'Not assigned' ].index
FullTorontoList.drop(indexNames , inplace=True)
FullTorontoList.reset_index(drop=True)
# Out:
#     Postalcode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M6A        North York
# 5          M6A        North York
# 6          M7A      Queen's Park
# 7          M9A         Etobicoke
# 8          M1B       Scarborough
# 9          M1B       Scarborough
# 10         M3B        North York
# 11         M4B         East York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M5B  Downtown Toronto
# 15         M6B        North York
# 16         M9B         Etobicoke
# 17         M9B         Etobicoke
# 18         M9B         Etobicoke
# 19         M9B         Etobicoke
# 20         M9B         Etobicoke
# 21         M1C       Scarborough
# 22         M1C       Scarborough
# 23         M1C       Scarborough
# 24         M3C        North York
# 25         M3C        North York
# 26         M4C         East York
# 27         M5C  Downtown Toronto
# 28         M6C              York
# 29         M9C         Etobicoke
# ..         ...               ...
# 181        M9V         Etobicoke
# 182        M1W       Scarborough
# 183        M4W  Downtown Toronto
# 184        M5W  Downtown Toronto
# 185        M8W         Etobicoke
# 186        M8W         Etobicoke
# 187        M9W         Etobicoke
# 188        M1X       Scarborough
# 189        M4X  Downtown Toronto
# 190        M4X  Downtown Toronto
# 191        M5X  Downtown Toronto
# 192        M5X  Downtown Toronto
# 193        M8X         Etobicoke
# 194        M8X         Etobicoke
# 195        M8X         Etobicoke
# 196        M4Y  Downtown Toronto
# 197        M7Y      East Toronto
# 198        M8Y         Etobicoke
# 199        M8Y         Etobicoke
# 200        M8Y         Etobicoke
# 201        M8Y         Etobicoke
# 202        M8Y         Etobicoke
# 203        M8Y         Etobicoke
# 204        M8Y         Etobicoke
# 205        M8Y         Etobicoke
# 206        M8Z         Etobicoke
# 207        M8Z         Etobicoke
# 208        M8Z         Etobicoke
# 209        M8Z         Etobicoke
# 210        M8Z         Etobicoke
#
#                                           Neighborhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                                          Regent Park
# 4                                     Lawrence Heights
# 5                                       Lawrence Manor
# 6                                         Not assigned
# 7                                     Islington Avenue
# 8                                                Rouge
# 9                                              Malvern
# 10                                     Don Mills North
# 11                                    Woodbine Gardens
# 12                                       Parkview Hill
# 13                                             Ryerson
# 14                                     Garden District
# 15                                           Glencairn
# 16                                          Cloverdale
# 17                                           Islington
# 18                                        Martin Grove
# 19                                    Princess Gardens
# 20                                     West Deane Park
# 21                                      Highland Creek
# 22                                          Rouge Hill
# 23                                          Port Union
# 24                                     Flemingdon Park
# 25                                     Don Mills South
# 26                                    Woodbine Heights
# 27                                      St. James Town
# 28                                  Humewood-Cedarvale
# 29                                   Bloordale Gardens
# ..                                                 ...
# 181                                        Thistletown
# 182                                    L'Amoreaux West
# 183                                           Rosedale
# 184                    Stn A PO Boxes 25 The Esplanade
# 185                                          Alderwood
# 186                                        Long Branch
# 187                                          Northwest
# 188                                        Upper Rouge
# 189                                        Cabbagetown
# 190                                     St. James Town
# 191                               First Canadian Place
# 192                                   Underground city
# 193                                       The Kingsway
# 194                                    Montgomery Road
# 195                                     Old Mill North
# 196                               Church and Wellesley
# 197  Business Reply Mail Processing Centre 969 Eastern
# 198                                         Humber Bay
# 199                                   King's Mill Park
# 200                           Kingsway Park South East
# 201                                          Mimico NE
# 202                                     Old Mill South
# 203                                 The Queensway East
# 204                              Royal York South East
# 205                                           Sunnylea
# 206                           Kingsway Park South West
# 207                                          Mimico NW
# 208                                 The Queensway West
# 209                              Royal York South West
# 210                                     South of Bloor
#
# [211 rows x 3 columns]

# %%
FullTorontoList.head()
# Out:
#   Postalcode           Borough      Neighborhood
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront
# 5        M5A  Downtown Toronto       Regent Park
# 6        M6A        North York  Lawrence Heights

# %%
FullTorontoList.shape
# Out:
# (211, 3)

# %%
#add language to w-get the csv file with zipcodes
# !wget -O Geospatial_Coordinates.csv https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Out:
# --2019-09-24 22:23:50--  https://cocl.us/Geospatial_data/Geospatial_Coordinates.csv
# Resolving cocl.us (cocl.us)... 169.48.113.194
# Connecting to cocl.us (cocl.us)|169.48.113.194|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-09-24 22:23:54--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-09-24 22:23:54--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-09-24 22:23:54--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!AMav3z5r-mLp6enwvvthsOcXjvGSsrXnO7oj8ek-zKYb9VTFHoG49TQTAiNVO7wStgZX6_L5zBqUPKIiqorfDwMcISNEuFe6Nf6aXn_2AhT9I2GGNnO7_nqnm7GnWTMQbCfnA2-wHMZQBaJc00GHZIpwBUhKAf0X0e_gLaVyPxQj56BXSsGNC_-uYhICH497jziJ0zwLOD7VMU0KsrNolH0S9HAKKnNs3oWDBf2wGiCSP8fV0C0yJA2Mh9B7dEWBwPbyPcUAPJbNiNitF8TsCC-klDjzRGBY4pU3dtMib-dRa81qJZJHEBW_zhp9RTVY492ctN_8SHfjLrIjoCCSUISoyglSMu3RH9oPCHvF3j-RQwXSUdZbBBEveDNz1yh2WtTvwkiF5xJaB4uSHkzDAcJnY-SHKl3Z3E_i4OwERylX4IDXXet6RVgQD2CBJRC0Q-Vz2lA_MKDFfrpBmAFNQO4O2ldyHu5CQEvRHp04_1poPZcThIRKr-llut5fXzGTWg1kGV3Ya-XoE9EsbWY__G5I1np61c3xC9OgLzfdaY5lyl9U-wDs4Se9cSA93aHKMOU0kUPWIRX2aHhCqEO9A_59eT4MHMQ_RdyQUyuHm84IsMrutpMtwQxKiVLr7AIm9WUg6hSkmAuLaju5R4x6CSNHKpHjGXFzqdiMjYwVNjYeYPctAr5KZG1own8Tsj4pj8lCkxFPxixnISojn5TfeSpepjThfnQMAIWm4VIcRxWPhBOel3wnaSxaBUfUAkC9V40_y4QJjBB-atg5dHSyaij2paw-Om4B3IZfuCgmAi6-eHoO2rmfqIp0Z_xsNdpA-BdtEy89dtxcd5sBOdBRT96FPV1B0YZ_9DyUV55GLTMqbkUr1jd4DjlO5ZdkxsfcHWFRkx6BVqyXOuOOP8El4STPMXNknDtMcjvodpBzqWR7f2jOg2k8xEbJ_alOJgOrHIQPGdgroe0AylfRk_5MhdWpvYiQhWOoV-a7qyEByFjyMttV-heV7XG3kxvgt8GHWU-Pzvpx9lU9s-lIL1rrl_K4I9WLHn3B5s2xaC9HfpEff8XC8dknM2JuQdAJqlrlJhDBvNalqFp1a6t9iqmH32ZA7Oiyjz_06IhjzsYqhgouhlAjlbLJ8H7VhAvC9y82pBWE_S1Jnl6GL6Us39tfkZAnbSndfD8Lbxg_Gs-uSSg6oRvd90LW6ztuGcagILqQTUK61uTb1CuOJJfAq1gBpYRJxXdAIyeMbeRuRoABmYpSdv7rVYGI1vLEekk9WkiT96sfowC2pusuRMatkGaylK4z-rDCVXa8aaGhcviKC6Z-IARhWQOKxAvpOkuXGPPYa4ylJUj9jEyaIR8CrthbLyk2wVQmih3UxZIC9ttP2c4lFRq4SzMSu_WcCKY./download [following]
# --2019-09-24 22:23:55--  https://public.boxcloud.com/d/1/b1!AMav3z5r-mLp6enwvvthsOcXjvGSsrXnO7oj8ek-zKYb9VTFHoG49TQTAiNVO7wStgZX6_L5zBqUPKIiqorfDwMcISNEuFe6Nf6aXn_2AhT9I2GGNnO7_nqnm7GnWTMQbCfnA2-wHMZQBaJc00GHZIpwBUhKAf0X0e_gLaVyPxQj56BXSsGNC_-uYhICH497jziJ0zwLOD7VMU0KsrNolH0S9HAKKnNs3oWDBf2wGiCSP8fV0C0yJA2Mh9B7dEWBwPbyPcUAPJbNiNitF8TsCC-klDjzRGBY4pU3dtMib-dRa81qJZJHEBW_zhp9RTVY492ctN_8SHfjLrIjoCCSUISoyglSMu3RH9oPCHvF3j-RQwXSUdZbBBEveDNz1yh2WtTvwkiF5xJaB4uSHkzDAcJnY-SHKl3Z3E_i4OwERylX4IDXXet6RVgQD2CBJRC0Q-Vz2lA_MKDFfrpBmAFNQO4O2ldyHu5CQEvRHp04_1poPZcThIRKr-llut5fXzGTWg1kGV3Ya-XoE9EsbWY__G5I1np61c3xC9OgLzfdaY5lyl9U-wDs4Se9cSA93aHKMOU0kUPWIRX2aHhCqEO9A_59eT4MHMQ_RdyQUyuHm84IsMrutpMtwQxKiVLr7AIm9WUg6hSkmAuLaju5R4x6CSNHKpHjGXFzqdiMjYwVNjYeYPctAr5KZG1own8Tsj4pj8lCkxFPxixnISojn5TfeSpepjThfnQMAIWm4VIcRxWPhBOel3wnaSxaBUfUAkC9V40_y4QJjBB-atg5dHSyaij2paw-Om4B3IZfuCgmAi6-eHoO2rmfqIp0Z_xsNdpA-BdtEy89dtxcd5sBOdBRT96FPV1B0YZ_9DyUV55GLTMqbkUr1jd4DjlO5ZdkxsfcHWFRkx6BVqyXOuOOP8El4STPMXNknDtMcjvodpBzqWR7f2jOg2k8xEbJ_alOJgOrHIQPGdgroe0AylfRk_5MhdWpvYiQhWOoV-a7qyEByFjyMttV-heV7XG3kxvgt8GHWU-Pzvpx9lU9s-lIL1rrl_K4I9WLHn3B5s2xaC9HfpEff8XC8dknM2JuQdAJqlrlJhDBvNalqFp1a6t9iqmH32ZA7Oiyjz_06IhjzsYqhgouhlAjlbLJ8H7VhAvC9y82pBWE_S1Jnl6GL6Us39tfkZAnbSndfD8Lbxg_Gs-uSSg6oRvd90LW6ztuGcagILqQTUK61uTb1CuOJJfAq1gBpYRJxXdAIyeMbeRuRoABmYpSdv7rVYGI1vLEekk9WkiT96sfowC2pusuRMatkGaylK4z-rDCVXa8aaGhcviKC6Z-IARhWQOKxAvpOkuXGPPYa4ylJUj9jEyaIR8CrthbLyk2wVQmih3UxZIC9ttP2c4lFRq4SzMSu_WcCKY./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordinates.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2019-09-24 22:23:55 (252 MB/s) - ‘Geospatial_Coordinates.csv’ saved [2891/2891]

# %%
#add language to open the csv file, read it into a dataframe called df_zip
df_zip = pd.read_csv('Geospatial_Coordinates.csv')
df_zip.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_zip.rename(columns={'Postal Code':'PostalCode'},inplace=True)
FullTorontoList.rename(columns={'Postalcode':'PostalCode'},inplace=True)
df_zip.head()
# Out:
#   PostalCode   Latitude  Longitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476

# %%
#add language to join the two data frames on the Postalcode
FTL_Final = FullTorontoList.merge(df_zip, left_on = 'PostalCode', right_on = 'PostalCode')

# %%
FTL_Final.head()
# Out:
#   PostalCode           Borough      Neighborhood   Latitude  Longitude
# 0        M3A        North York         Parkwoods  43.753259 -79.329656
# 1        M4A        North York  Victoria Village  43.725882 -79.315572
# 2        M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3        M5A  Downtown Toronto       Regent Park  43.654260 -79.360636
# 4        M6A        North York  Lawrence Heights  43.718518 -79.464763
